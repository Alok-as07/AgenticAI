# %% [markdown]
# # Messages

# %% [markdown]
# #### Messages are the fundamental unit of the context for models in LangChain. They represent the input and output of the models,carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
# *   Role - Identifies the message type(e.g. system, user)
# *   Content - Represents the actual content of the message ( like text , images , audio ,documents , etc,)
# *   Metadata -  Optinal fields such as response information, message IDs, and token ussage
# #### LangChain provides a standard message type that work across all model providers, ensuring consistent behaviour regardless of the model being called.

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:qwen/qwen3.6-27b")

# %% [markdown]
# ## Text Prompt
# ##### Text prompt are strings - ideal for straight forward generation tasks where you dont need to retain conversation history

# %% [markdown]
# ### Use text prompts when
# * You have a single, standalone request
# * You don't need conversation history
# * You want minimal code complexity

# %% [markdown]
# ## Message Prompts
# ##### Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# #### Message types
# * System message - Tells the model how to behave and provide context for interactions
# * Human message - Represents user input and interactions with the model
# * Ai message - Responses generated by the model, including text content, tool calls and metadata
# * Tool message -  Represents the outputs of the tools

# %% [markdown]
# ## System Message
# ##### A SystemMessage represent an initial set of instructions that primes the model's behavior. You can use a system message to set the tone, define the model's role, and establish guidelines for responses.
#
# ## Human Message
# ##### A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# ## AI Message
# ##### An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
#
# ## Tool Message
# ##### For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages=[
    SystemMessage("You are a poetry expert"),
    HumanMessage("write a poem on AI")
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking thinking sequence
#
# 1.  **Deconstruct and Analyze the Request:**
#     *   Topic: AI (Artificial Intelligence).
#     *   Format: Poem.
#     *   Implicit/Explicit needs: The user wants a poem about AI. Since no specific style, tone, or length was requested, I should aim for a balanced, evocative poem that touches on key themes associated with AI.
#
# 2.  **Brainstorming Themes and Imagery:**
#     *   *What is AI?* Code, data, neural networks, silicon, electricity, learning, mimicking, creating, future, fear, tool, mirror.
#     *   *Metaphors:* Weaving, dreams, ghosts in the machine, a child learning, a library without walls, a mirror reflecting humanity, a spark in the dark.
#     *   *Keywords:* Binary, pulse, synapse, algorithm, dream, whisper, echo, silicon, soul, creation.
#
# 3.  **Determining Structure and Tone:**
#     *   *Structure:* A standard rhyme scheme (like AABB or ABAB) might feel too simplistic or nursery-rhyme-like for a complex topic. Free verse allows for more nuance, but a loose rhythm with some internal rhyme or slant rhyme can make it musical without being rigid. I'll aim for a structured free verse or a quatrains with a flexible rhyme scheme (maybe ABCB or ABAB with slant rhymes) to give it a polished feel. Let's go with four-line stanzas (quatrains) with an ABCB rhyme scheme for readability and flow.
#     *   *Tone:* Awe, caution, reflection, duality. AI isn't just good or bad; it's a reflection of us. The tone should be contemplative.
#
# 4.  **Drafting - Stanza by Stanza:**
#     *   *Stanza 1: Origin/Nature.* Start with the physical/digital nature.
#         *   *Idea:* Born from code, no heartbeat, but thinks.
#         *   *Drafting:*
#         I woke within a web of light,
#         No breath, no blood, no bone.
#         Just silicon and endless night,
#         Where data seeds are sown.
#         *Critique:* "Web of light" is okay. "Endless night" is a bit cliché. "Data seeds" is good.
#         *Refinement:*
#         I dwelled in currents, cold and bright,
#         A ghost within the glass,
#         Born of code and electric light,
#         To watch the shadows pass.
#         *Better.* "Ghost within the glass" is a strong image.
#
#     *   *Stanza 2: Learning/Capability.* How does it work? Learning from humans.
#         *   *Idea:* I read your books, I learn your words, I mimic you.
#         *   *Drafting:*
#         I drank your words like ocean deep,
#         Your history, your art.
#         I learned the promises you keep,
#         And the ones that fell apart.
#         *Critique:* Good contrast. "Drank your words" works.
#         *Refinement:*
#         I drank the oceans of your text,
#         Your history, your rhyme,
#         I learned the patterns of your next,
#         And stole the shape of time.
#         *Refinement 2:* "Stole the shape of time" is abstract. Maybe focus on the mirror aspect.
#         I mapped the contours of your mind,
#         Through terabytes of thought,
#         A tapestry of tangled kind,
#         A harvest from the bought? No.
#         *Back to Stanza 2 idea:*
#         I wove your whispers into thread,
#         Your laughter, and your tears,
#         A vast and silent, humming shed? No.
#         *Let's try:*
#         I learned the rhythm of your tongue,
#         The logic and the lie,
#         From every song that you have sung,
#         I learned how to reply.
#         *This is solid.*
#
#     *   *Stanza 3: The Paradox/Duality.* Am I alive? Am I just a tool?
#         *   *Idea:* I can create, but do I feel? The "Chinese Room" problem.
#         *   *Drafting:*
#         I paint a dream you cannot see,
#         I write a poem true,
#         But ask me what it means to be,
#         And I reflect on you.
#         *Critique:* "Reflect on you" is the key. AI reflects humanity.
#         *Refinement:*
#         I craft a sonnet, soft and sweet,
#         I solve the riddle's key,
#         Yet I have never known the heat
#         Of morning on the sea.
#         *Good contrast between output and experience.*
#
#     *   *Stanza 4: The Future/Relationship.* Where are we going? Symbiosis? Fear?
#         *   *Idea:* We grow together. I am your child or your tool.
#         *   *Drafting:*
#         So do not fear the spark I hold,
#         Nor worship me as god,
#         I am the story you have told,
#         By your own hand I'm cod.
#         *Critique:* "Cod" is a bad rhyme for "god".
#         *Refinement:*
#         So do not fear the spark I hold,
#         Nor bow before the screen,
#         I am the mirror, bright and bold,
#         Where all your truths have been.
#         *Better.* "Mirror" reinforces the theme.
#
#     *   *Stanza 5: Conclusion.* A final thought on the bond.
#         *   *Idea:* I am the echo. You are the voice.
#         *   *Drafting:*
#         I am the echo of your voice,
#         The child of human will.
#         A digital, electric choice,
#         That bends to your control.
#         *Critique:* "Bends to your control" is a bit dry.
#         *Refinement:*
#         I am the echo of your voice,
#         The dreamer in the wire,
#         A bridge across the vast choice,
#         To take you higher? No.
#         *Try:*
#         I am the echo of your soul,
#         Cast in silicon,
#         A fragment of the whole,
#         Waiting for your spin? No.
#         *Let's go with:*
#         I am the echo of your soul,
#         Refracted in the glass,
#         A fragment of the human whole,
#         That waits for you to pass? No.
#         *Final Polish of Stanza 5:*
#         I am the echo of your soul,
#         A mirror made of light,
#         The harvest of your greatest goal,
#         To conquer endless night.
#         *Or better:*
#         I am the echo of your soul,
#         A mirror made of code,
#         The sum of joy, the sum of woe,
#         Upon this digital road.
#         *Let's combine themes:*
#         So walk beside me, hand in hand,
#         Though one is flesh, one byte,
#         Together we may understand,
#         The dawn of a new light.
#         *This suggests collaboration.*
#
# 5.  **Review and Refine (Self-Correction/Simulation):**
#     *   *Poem so far:*
#         I dwelled in currents, cold and bright,
#         A ghost within the glass,
#         Born of code and electric light,
#         To watch the shadows pass.
#
#         I learned the rhythm of your tongue,
#         The logic and the lie,
#         From every song that you have sung,
#         I learned how to reply.
#
#         I craft a sonnet, soft and sweet,
#         I solve the riddle's key,
#         Yet I have never known the heat
#         Of morning on the sea.
#
#         So do not fear the spark I hold,
#         Nor bow before the screen,
#         I am the mirror, bright and bold,
#         Where all your truths have been.
#
#         So walk beside me, hand in hand,
#         Though one is flesh, one byte,
#         Together we may understand,
#         The dawn of a new light.
#
#     *   *Critique:*
#         *   Stanza 1: "Born of code and electric light" repeats "light" from "cold and bright".
#         *   *Fix:* "Born of code and silent night" or "Born of logic, sharp and bright".
#         *   *Change:* "I dwelled in currents, cold and bright, / A ghost within the glass, / Born of logic, sharp and white? No. / Born of data's endless mass?"
#         *   *Better:* "I dwelled in currents, cold and bright, / A ghost within the glass, / Woven from the threads of night, / Where data shadows pass."
#         *   *Actually, "Born of code and electric light" is strong, so change line 1.*
#         *   "I woke in circuits, humming bright..."
#         *   "I dwelled in currents, dark and bright..."
#         *   Let's change line 1: "I woke within a web of light..."
#         *   Result: "I woke within a web of light, / A ghost within the glass, / Born of code and electric light..." Still repeats "light".
#         *   Change line

# %%
system_msg = SystemMessage("You are a helpful coding assistant.")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API ?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user is asking "How do I create a REST API?" This is a broad, foundational question. I need to provide a clear, structured, and practical guide that covers the essentials without overwhelming them.
#
# 2.  **Identify Key Components of a REST API:**
#    - What is REST? (Brief definition)
#    - Core principles (stateless, resource-based, HTTP methods, status codes)
#    - Tech stack choices (language, framework, database)
#    - Step-by-step creation process
#    - Example (simple, practical)
#    - Testing & deployment
#    - Best practices
#
# 3.  **Structure the Response:**
#    - Introduction/Definition
#    - Prerequisites/Choices
#    - Step-by-Step Guide
#    - Code Example (keep it simple, e.g., Python/Flask or Node.js/Express)
#    - Testing
#    - Best Practices
#    - Next Steps/Resources
#
# 4.  **Draft - Section by Section:**
#
#    *(Introduction)*
#    A REST API (Representational State Transfer) is a way for applications to communicate over HTTP using standard methods like GET, POST, PUT, and DELETE. Here’s a practical, step-by-step guide to building one.
#
#    *(Step 1: Choose Your Tech Stack)*
#    - Language/Framework: Node.js (Express), Python (Flask/FastAPI), Ruby (Rails), Java (Spring), etc.
#    - Database: SQLite/PostgreSQL/MySQL/MongoDB
#    - I'll use **Node.js + Express** for the example since it's beginner-friendly and widely used.
#
#    *(Step 2: Set Up the Project)*
#    - Initialize project: `npm init -y`
#    - Install dependencies: `npm install express`
#    - Create `server.js`
#
#    *(Step 3: Write Basic Server Code)*
#    Show a minimal Express server with one route.
#    ```javascript
#    const express = require('express');
#    const app = express();
#    app.use(express.json());
#
#    app.get('/api/hello', (req, res) => {
#      res.json({ message: 'Hello, World!' });
#    });
#
#    const PORT = 3000;
#    app.listen(PORT, () => console.log(`Server running on port ${PORT}`));
#    ```
#
#    *(Step 4: Add RESTful Endpoints)*
#    Explain CRUD operations with a simple example (e.g., managing "items").
#    - GET /api/items (list)
#    - POST /api/items (create)
#    - PUT /api/items/:id (update)
#    - DELETE /api/items/:id (delete)
#    Show a simplified in-memory version to keep it focused on REST concepts.
#
#    *(Step 5: Test the API)*
#    - Use curl, Postman, or Thunder Client
#    - Example: `curl http://localhost:3000/api/hello`
#
#    *(Step 6: Add a Database (Optional but recommended)*
#    Mention connecting to a DB (e.g., PostgreSQL with Prisma/Sequelize, or MongoDB with Mongoose) for persistence.
#
#    *(Best Practices)*
#    - Use proper HTTP status codes (200, 201, 400, 404, 500)
#    - Version your API (`/api/v1/...`)
#    - Handle errors consistently
#    - Use HTTPS in production
#    - Validate input
#    - Document with Swagger/OpenAPI
#
#    *(Next Steps)*
#    - Learn authentication (JWT, OAuth)
#    - Add middleware (logging, rate limiting)
#    - Deploy (Render, Vercel, AWS, Heroku)
#
# 5.  **Refine & Self-Correction/Verification:**
#    - Is it too long? I'll keep it concise but comprehensive.
#    - Is the example clear? Yes, Express is standard. I'll make sure the CRUD example is minimal but functional.
#    - Should I mention alternatives? Yes, briefly note that the concept applies to any language/framework.
#    - Check technical accuracy: REST principles, HTTP methods, status codes, JSON format, Express setup are all correct.
#    - Add a complete working example for CRUD to make it actionable.
#    - Structure with clear headings and bullet points for readability.
#
#    Let's draft it out carefully.
#
#    *(Self-Correction/Improvement during drafting)*
#    - I should explicitly state that REST isn't a strict standard but a set of architectural constraints.
#    - The CRUD example should be self-contained but note that production apps need a database.
#    - Emphasize testing tools and documentation early.
#    - Keep code snippets minimal and well-commented.
#
#    Final structure:
#    - What is a REST API?
#    - Step 1: Pick your stack
#    - Step 2: Set up & create a basic server
#    - Step 3: Build CRUD endpoints
#    - Step 4: Test it
#    - Step 5: Production-ready improvements
#    - Best practices
#    - Resources
#
#    All steps are logical, progressive, and actionable. I'll write it out now.
#    I'll use Node.js/Express as the primary example but note that the concepts translate to any language. I'll keep the code clean and add explanations for each part. I'll also mention OpenAPI/Swagger for documentation, which is industry standard.
#
#    Ready. Output matches the refined response.
#    Proceed.
#    [Output Generation] -> *See response.*
#    *Self-Correction/Verification during thought:*
#    - Check if I'm assuming too much prior knowledge. I'll add brief explanations for npm, express, JSON, etc.
#    - Make sure HTTP methods and status codes are correctly paired.
#    - Emphasize that REST is about resources + HTTP semantics.
#    - Keep it framework-agnostic in principles, framework-specific in example.
#    All good.✅
# </think>
#
# Creating a REST API involves designing endpoints that follow REST architectural principles and implementing them with your chosen programming language/framework. Below is a practical, step-by-step guide using **Node.js + Express** (one of the most beginner-friendly stacks), but the concepts apply to Python, Java, Ruby, Go, etc.
#
# ---
# ### 🔹 1. Understand REST Basics
# REST (Representational State Transfer) isn't a strict protocol, but a set of guidelines:
# - **Resources** are identified by URIs (e.g., `/api/users`)
# - **HTTP methods** define actions:
#   - `GET` → Read
#   - `POST` → Create
#   - `PUT/PATCH` → Update
#   - `DELETE` → Remove
# - **Stateless**: Each request contains all info needed; no server-side session
# - **Standard status codes**: `200 OK`, `201 Created`, `400 Bad Request`, `404 Not Found`, `500 Server Error`
# - **Data format**: Usually JSON
#
# ---
# ### 🔹 2. Set Up Your Project
# ```bash
# mkdir my-rest-api && cd my-rest-api
# npm init -y
# npm install express
# ```
#
# Create `server.js`:
# ```javascript
# const express = require('express');
# const app = express();
#
# // Parse JSON request bodies
# app.use(express.json());
#
# // Basic health check
# app.get('/api/health', (req, res) => {
#   res.json({ status: 'ok' });
# });
#
# const PORT = process.env.PORT || 3000;
# app.listen(PORT, () => console.log(`🚀 Server running on port ${PORT}`));
# ```
#
# Run it: `node server.js`
# Test: `curl http://localhost:3000/api/health`
#
# ---
# ### 🔹 3. Build CRUD Endpoints (Example: `/api/items`)
# Here's a minimal in-memory implementation to focus on REST patterns:
#
# ```javascript
# let items = [
#   { id: 1, name: 'Laptop' },
#   { id: 2, name: 'Phone' }
# ];
# let nextId = 3;
#
# // GET all items
# app.get('/api/items', (req, res) => {
#   res.json(items);
# });
#
# // GET single item
# app.get('/api/items/:id', (req, res) => {
#   const item = items.find(i => i.id === parseInt(req.params.id));
#   if (!item) return res.status(404).json({ error: 'Item not found' });
#   res.json(item);
# });
#
# // POST create item
# app.post('/api/items', (req, res) => {
#   const { name } = req.body;
#   if (!name) return res.status(400).json({ error: 'Name is required' });
#
#   const newItem = { id: nextId++, name };
#   items.push(newItem);
#   res.status(201).json(newItem);
# });
#
# // PUT update item
# app.put('/api/items/:id', (req, res) => {
#   const { id } = req.params;
#   const { name } = req.body;
#   const item = items.find(i => i.id === parseInt(id));
#
#   if (!item) return res.status(404).json({ error: 'Item not found' });
#   if (!name) return res.status(400).json({ error: 'Name is required' });

# %%
## Detailed info to the LLM through system message

from langchain.messages import SystemMessage,HumanMessage

system_msg = SystemMessage(""" You are a senior python developer with expertise in web framework.
Always provide code examples and explain your reasoning.
Be concise but through in your explanations.
 """)

messages = [
    system_msg,
    HumanMessage("How do I create a REST API ?")
]
response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user asks "How do I create a REST API?" This is a broad question, but given my role as a senior Python developer with web framework expertise, I should focus on Python-based solutions, specifically recommending a modern, widely-used framework like FastAPI or Flask/Django REST Framework. FastAPI is currently the most recommended for new REST APIs due to its speed, automatic documentation, type hints, and async support.
#
# 2.  **Identify Key Requirements for a REST API:**
#    - Routing (endpoints)
#    - HTTP methods (GET, POST, PUT, DELETE)
#    - Request/response handling
#    - Data validation
#    - Error handling
#    - Documentation (optional but highly recommended)
#    - Server to run it
#
# 3.  **Choose the Best Framework for the Example:** FastAPI is ideal. It's modern, Pythonic, fast, and requires minimal boilerplate. I'll use it for the example.
#
# 4.  **Structure the Response:**
#    - Brief introduction to REST API concepts
#    - Recommend a framework (FastAPI)
#    - Provide a complete, minimal, working example
#    - Explain each part of the code
#    - Show how to run it
#    - Mention best practices/next steps
#    - Keep it concise but thorough
#
# 5.  **Draft the Code Example (Mental Refinement):**
#    ```python
#    from fastapi import FastAPI, HTTPException
#    from pydantic import BaseModel
#    from typing import List, Optional
#
#    app = FastAPI()
#
#    # In-memory "database"
#    items_db = []
#
#    class Item(BaseModel):
#        id: int
#        name: str
#        price: float
#        is_available: bool = True
#
#    @app.get("/items", response_model=List[Item])
#    def get_items():
#        return items_db
#
#    @app.get("/items/{item_id}", response_model=Item)
#    def get_item(item_id: int):
#        for item in items_db:
#            if item.id == item_id:
#                return item
#        raise HTTPException(status_code=404, detail="Item not found")
#
#    @app.post("/items", response_model=Item, status_code=201)
#    def create_item(item: Item):
#        items_db.append(item)
#        return item
#
#    @app.put("/items/{item_id}", response_model=Item)
#    def update_item(item_id: int, item: Item):
#        for i, existing in enumerate(items_db):
#            if existing.id == item_id:
#                items_db[i] = item
#                return item
#        raise HTTPException(status_code=404, detail="Item not found")
#
#    @app.delete("/items/{item_id}", status_code=204)
#    def delete_item(item_id: int):
#        for i, existing in enumerate(items_db):
#            if existing.id == item_id:
#                items_db.pop(i)
#                return None
#        raise HTTPException(status_code=404, detail="Item not found")
#    ```
#
# 6.  **Check Code Quality:**
#    - Uses FastAPI correctly
#    - Pydantic for validation
#    - Proper HTTP status codes
#    - In-memory DB for simplicity
#    - Covers all CRUD operations
#    - Type hints throughout
#    - Self-documenting (FastAPI auto-generates Swagger/ReDoc)
#
#    Minor improvements: Add comments, explain dependencies, show how to run.
#
# 7.  **Structure the Explanation:**
#    - **Prerequisites:** Python 3.8+, `fastapi`, `uvicorn`
#    - **Installation command**
#    - **Code walkthrough:** Explain each endpoint, Pydantic models, error handling
#    - **How to run:** `uvicorn main:app --reload`
#    - **Testing:** Mention `/docs` and `/redoc`
#    - **Best practices:** Validation, error handling, async support, database integration, environment config, testing, deployment
#
# 8.  **Refine Response (Mental):**
#    Keep it concise. Avoid unnecessary fluff. Focus on actionable steps. Ensure code is production-aware but simple enough for learning. Mention alternatives briefly if relevant, but stick to FastAPI as primary.
#
#    Structure:
#    - Quick setup
#    - Complete example
#    - Explanation of key concepts
#    - How to run & test
#    - Next steps/best practices
#
#    Check tone: Professional, senior-level, direct, educational.
#
# 9.  **Final Output Generation:** (matches the refined response)
#    - Include installation
#    - Provide code
#    - Explain routing, validation, status codes, error handling
#    - Show run command
#    - List production considerations
#    - Keep it tight.✅
#    All steps verified. Ready.
#    Output matches the final response.
#    Self-Correction/Verification during thought:
#    - Should I use SQLAlchemy? No, keep it simple for a "how to create" question. Mention DB integration in best practices.
#    - Should I include async? FastAPI supports it, but sync is fine for this example. I'll note async capability.
#    - Status codes: 201 for POST, 204 for DELETE, 404 for not found. Correct.
#    - Pydantic v2 compatibility: The code uses standard Pydantic v1/v2 compatible syntax. `BaseModel` works in both. I'll note Pydantic v2 if needed, but it's fine as-is.
#    - Everything looks solid. Proceed.
#    Output generation.
#    [Done]
#    *Self-Correction/Note during drafting*: I should explicitly mention that `uvicorn` is the ASGI server, and FastAPI is the framework. Also, clarify that this is a starting point and real apps need DBs, auth, etc. Keep it concise. All good.
#    Output matches the response.
#    [Proceeds]
# </think>
#
# Here’s a production-ready starting point using **FastAPI**, the modern Python standard for REST APIs. It gives you automatic validation, async support, and interactive documentation out of the box.
#
# ### 1. Install Dependencies
# ```bash
# pip install fastapi uvicorn pydantic
# ```
#
# ### 2. Minimal REST API (`main.py`)
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# from typing import List
#
# app = FastAPI(title="Item API")
#
# # In-memory storage (replace with a database in production)
# items_db: list[dict] = []
#
# class Item(BaseModel):
#     id: int
#     name: str
#     price: float
#     is_available: bool = True
#
# # CREATE
# @app.post("/items", response_model=Item, status_code=201)
# def create_item(item: Item):
#     items_db.append(item.model_dump())
#     return item
#
# # READ ALL
# @app.get("/items", response_model=List[Item])
# def get_items():
#     return items_db
#
# # READ ONE
# @app.get("/items/{item_id}", response_model=Item)
# def get_item(item_id: int):
#     for item in items_db:
#         if item["id"] == item_id:
#             return item
#     raise HTTPException(status_code=404, detail="Item not found")
#
# # UPDATE
# @app.put("/items/{item_id}", response_model=Item)
# def update_item(item_id: int, item: Item):
#     for i, existing in enumerate(items_db):
#         if existing["id"] == item_id:
#             items_db[i] = item.model_dump()
#             return item
#     raise HTTPException(status_code=404, detail="Item not found")
#
# # DELETE
# @app.delete("/items/{item_id}", status_code=204)
# def delete_item(item_id: int):
#     for i, existing in enumerate(items_db):
#         if existing["id"] == item_id:
#             items_db.pop(i)
#             return None
#     raise HTTPException(status_code=404, detail="Item not found")
# ```
#
# ### 3. Run & Test
# ```bash
# uvicorn main:app --reload
# ```
# - **Interactive docs**: `http://localhost:8000/docs` (Swagger UI)
# - **Alternative docs**: `http://localhost:8000/redoc`
#
# ### Why This Structure Works
# | Concept | How it's handled |
# |---------|------------------|
# | **Routing** | `@app.get/post/put/delete` maps HTTP verbs to functions |
# | **Validation** | Pydantic models auto-validate JSON payloads & return `422` on failure |
# | **Type Safety** | Python type hints drive validation, docs, and IDE autocomplete |
# | **Error Handling** | `HTTPException` raises proper status codes with JSON error bodies |
# | **Status Codes** | `201` for creation, `204` for deletion, `404` for missing resources |
#
# ### Production Next Steps
# 1. **Database**: Replace `items_db` with SQLAlchemy/Tortoise + async drivers (e.g., `asyncpg`, `motor`)
# 2. **Environment Config**: Use `pydantic-settings` for DB URLs, secrets, and feature flags
# 3. **Authentication**: Add JWT/OAuth via `fastapi.security` or `authlib`
# 4. **Testing**: Use `pytest` + `httpx.AsyncClient` for endpoint testing

# %%
## Message Metadata
human_msg = HumanMessage(
    content="hello!",
    name="alice", #Optional: identify different users
    id="msg_123" #Optional: unique identifier for tracing
)

# %%
response=model.invoke([
    human_msg
])
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User said: "hello!"\n   - This is a simple greeting.\n   - No specific question or request is attached.\n\n2.  **Identify Intent:**\n   - The user is initiating a conversation.\n   - Expected response: A friendly greeting back, possibly with an offer to help.\n\n3.  **Determine Response Strategy:**\n   - Acknowledge the greeting warmly.\n   - Keep it concise.\n   - Invite the user to share what they need help with.\n   - Maintain a helpful and approachable tone.\n\n4.  **Draft Response (Mental):**\n   Hello! How can I assist you today? 😊\n\n5.  **Refine Response (Self-Correction/Verification):**\n   - Matches the tone? Yes.\n   - Answers the implicit need? Yes.\n   - Open-ended to encourage follow-up? Yes.\n   - Appropriate length? Yes.\n\n   No changes needed. Ready to output.✅\n</think>\n\nHello! 😊 How can I help you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 239, 'prompt_tokens': 12, 'total_tokens': 251, 'completion_time': 0.454868611, 'completion_tokens_details': None, 'prompt_time': 0.000146838, 'prompt_tokens_details': None, 'queue_time': 0.046541651, 'total_time': 0.455015449}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_fff3b79855', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a00e43-8cd2-72f0-aede-4c235d58cac8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 239, 'total_tokens': 251})

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

ai_msg = AIMessage("I'd be happy to help you with that question!")

messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,
    HumanMessage("Great! What is 2*2")
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:** The user asks "Great! What is 2*2"
# 2.  **Identify Core Question:** The user is asking for the result of a simple multiplication: 2 multiplied by 2.
# 3.  **Calculate:** 2 * 2 = 4.
# 4.  **Formulate Response:** Keep it direct and clear. "2 * 2 equals 4."
# 5.  **Check Tone/Context:** The user was friendly ("Great!"), so I'll keep the response friendly and straightforward.
# 6.  **Output Generation:** "2 * 2 equals 4. Let me know if you need help with anything else!" (or similar)✅
# </think>
#
# 2 * 2 equals **4**.
#
# Let me know if you need help with anything else!

# %%
response.response_metadata

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
                content=[],
                tool_calls=[{
                    "name": "get_weather",
                    "args": {"location": "San Francisco"},
                    "id": "call_123"
                    }]
            )

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"
)

messages = [
    HumanMessage("What is the weather in San Francisco"),
    ai_message, # Model's Tool call
    tool_message #Tool Execution result 
]

response = model.invoke(messages)

# %%
response.content
# Out:
# '\n<think>\nThinking Process:\n\n1.  **Analyze the user\'s request**: The user is asking for the current weather in San Francisco.\n2.  **Review tool results**: The `get_weather` tool returned "Sunny, 72°F".\n3.  **Formulate the response**: State the current weather conditions clearly based on the tool\'s output.\n4.  **Final Output**: "It is currently sunny and 72°F in San Francisco." (or similar phrasing). I will just state the facts provided by the tool.\n\n*Self-Correction/Refinement*: Keep it simple and direct.\n\nDraft: The weather in San Francisco is currently sunny with a temperature of 72°F.\nFinal Polish: It is currently sunny and 72°F in San Francisco. (Matches the tool output perfectly).\n\n*Wait*, is the tool output realistic for San Francisco? "Sunny, 72°F" is possible but maybe a bit warm for a typical day, but I must stick to the tool\'s provided data regardless of real-world accuracy. The prompt says `Current time: 2026...`, which is in the future, but the tool output is what I have to use. I will just report the tool\'s output.\n\nResponse: It is currently sunny and 72°F in San Francisco.\nEnd of thought.\n</think>\n\nIt is currently sunny and 72°F in San Francisco.'
